# %%
# %run main.py
# Out:
# Sally: Hi, my name is Sally. I am a virtual assistant of Homeowners Choice powered by Artificial Intelligence. I can help you file a claim for Hurricane Isaac. If you get stuck, you can always restart our conversation by typing "restart". What should I do for you?
#
# User: Hi, I want to file a claim
# Sally: What is your 6-digit policy number?
#
# User: HCPCI-123-456
# Sally: Ok. Please tell me your full name?
#
# User: Krishnendu Sekhar Kar
# Sally: Got it. What is your property address?
#
# User: 63, Noida City Center, NOIDA
# Sally: Ok. Please give me a phone number to contact you. I will also share this number with the adjuster who will visit your property.
#
# User: 123-456-7864
# Sally: Got that. Please provide me with an email address where I will send the details of the claim.
#
# User: krish.0234@gmail.com
# Sally: When did the loss occur?
#
# User: Last night
# Sally: Can you please describe the loss?
#
# User: Yeah, roof and shingles got damaged
# ...

# %%
# %run main.py
# Out:
# Sally: Hi, my name is Sally. I am a virtual assistant of Homeowners Choice powered by Artificial Intelligence. I can help you file a claim for Hurricane Isaac. If you get stuck, you can always restart our conversation by typing "restart". What should I do for you?
#
# User: Hi, My policy number is HCPCI 123 456 and I want to file a claim
# Sally: Ok. Please tell me your full name?
#
# User: I am Chandrashekhar Kandpal
# Sally: Got it. What is your property address?
#
# User: 254 Lincoln St, Miami FL 409237
# Sally: Ok. Please give me a phone number to contact you. I will also share this number with the adjuster who will visit your property.
#
# User: 123 5894
# Sally: And the area code?
#
# User: 275
# Sally: Got that. Please provide me with an email address where I will send the details of the claim.
#
# User: c.shekhar@yahoo.com
# Sally: When did the loss occur?
#
# User: I wasn't home... maybe somewhere around midnight
# Sally: Can you please describe the loss?
#
# ...
